# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset (asegurarse de tenerlo en el directorio de trabajo)
file_path = "./data/big_startup_secsees_dataset.csv"  # Cambiar a la ruta correcta
startups_data = pd.read_csv(file_path)

# Analizar las principales métricas y valores del dataset
# Resumen estadístico
print("Resumen estadístico del dataset:")
print(startups_data.describe(include='all'))

# Distribución de estados (status)
plt.figure(figsize=(8, 5))
sns.countplot(data=startups_data, x='status', order=startups_data['status'].value_counts().index)
plt.title('Distribución de Status de las Startups', fontsize=16)
plt.xlabel('Status', fontsize=12)
plt.ylabel('Cantidad', fontsize=12)
plt.tight_layout()
plt.show()

# Principales categorías por cantidad
category_counts = startups_data['category_list'].value_counts().head(10)
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Top 10 Categorías de Startups', fontsize=16)
plt.xlabel('Categorías', fontsize=12)
plt.ylabel('Cantidad', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Distribución geográfica: principales países
country_counts = startups_data['country_code'].value_counts().head(10)
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='green')
plt.title('Top 10 Países con más Startups', fontsize=16)
plt.xlabel('País', fontsize=12)
plt.ylabel('Cantidad', fontsize=12)
plt.tight_layout()
plt.show()

# Relación entre funding_total_usd y status
plt.figure(figsize=(10, 6))
sns.boxplot(data=startups_data, x='status', y='funding_total_usd')
plt.yscale('log')  # Escala logarítmica para mejor visualización
plt.title('Distribución de Financiación Total por Status', fontsize=16)
plt.xlabel('Status', fontsize=12)
plt.ylabel('Financiación Total (USD)', fontsize=12)
plt.tight_layout()
plt.show()

# Correlación entre variables numéricas
numerical_columns = startups_data.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = startups_data[numerical_columns].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación entre Variables Numéricas', fontsize=16)
plt.tight_layout()
plt.show()

# Crear un gráfico de barras agrupado para 'status' y 'category_list'
main_categories = category_counts.index
filtered_data = startups_data[startups_data['category_list'].isin(main_categories)]
plt.figure(figsize=(12, 6))
sns.countplot(data=filtered_data, y='category_list', hue='status', order=main_categories)
plt.title('Distribución de Status por Principales Categorías', fontsize=16)
plt.xlabel('Cantidad', fontsize=12)
plt.ylabel('Categoría', fontsize=12)
plt.legend(title='Status', loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# Resumen estadístico del dataset:
#                                       permalink   name  \
# count                                     66368  66367
# unique                                    66368  66102
# top     /organization/zynergy-projects-services  Blink
# freq                                          1      4
# mean                                        NaN    NaN
# std                                         NaN    NaN
# min                                         NaN    NaN
# 25%                                         NaN    NaN
# 50%                                         NaN    NaN
# 75%                                         NaN    NaN
# max                                         NaN    NaN
#
#                       homepage_url category_list funding_total_usd     status  \
# count                        61310         63220             66368      66368
# unique                       61191         27296             18896          4
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    'cat_var1': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'] * 10,
    'cat_var2': ['X', 'Y', 'Z', 'X', 'Y', 'Z', 'X', 'Y', 'Z', 'X'] * 10,
    'cont_var': range(100)
}
df = pd.DataFrame(data)

# Seleccionar los primeros 20 valores únicos de 'cat_var1'
top_categories = df['cat_var1'].unique()[:20]
filtered_df = df[df['cat_var1'].isin(top_categories)]

# Crear el gráfico de barras agrupado por las categorías
plt.figure(figsize=(12, 6))
sns.barplot(data=filtered_df, x='cat_var1', y='cont_var', hue='cat_var2', ci=None)
plt.title("Gráfico de Barras para las Primeras 20 Categorías de 'cat_var1'")
plt.xlabel("Categoría (cat_var1)")
plt.ylabel("Valor Continuo Promedio (cont_var)")
plt.legend(title="Categoría (cat_var2)")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_11172\3481307707.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=filtered_df, x='cat_var1', y='cont_var', hue='cat_var2', ci=None)

# %%
df
# Out:
#    cat_var1 cat_var2  cont_var
# 0         A        X         0
# 1         B        Y         1
# 2         C        Z         2
# 3         D        X         3
# 4         E        Y         4
# ..      ...      ...       ...
# 95        F        Z        95
# 96        G        X        96
# 97        H        Y        97
# 98        I        Z        98
# 99        J        X        99
#
# [100 rows x 3 columns]
